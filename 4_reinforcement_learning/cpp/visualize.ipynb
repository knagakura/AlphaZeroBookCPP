# %%
# パッケージのインポート
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !./run.sh > out.csv
# Out:
# In file included from ./main.cpp:4:
# ./lib/EpsilonGreedy.cpp: In member function 'void EpsilonGreedy::update(int, int, int)':
# ./lib/EpsilonGreedy.cpp:34:45: warning: unused parameter 't' [-Wunused-parameter]
#    34 |     void update(int armIdx, int reward, int t) {
#       |                                         ~~~~^

# %%
df = pd.read_csv("out.csv", header = None)
plt.plot(df[1])
